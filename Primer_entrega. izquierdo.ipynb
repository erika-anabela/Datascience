# %% [markdown]
# Estadisticas delictuales CHILE

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

df_delitos= pd.read_excel ("estadisticas.delitos.xlsx")
print (df_delitos.head(10))
# Out:
#     AÑO  MES  Homicidios  Hurtos  Lesiones leves  Robos  Robo de vehículo   \
# 0  2010    1          28    9142            6723   4114               2270
# 1  2010    2          19    8083            5433   3568               2210
# 2  2010    3          18    7783            6527   3447               2375
# 3  2010    4          15    8432            6248   3587               2480
# 4  2010    5          14    9121            6189   3844               2632
# 5  2010    6          14    8998            5864   3988               2410
# 6  2010    7          12    9383            4991   4253               2674
# 7  2010    8          26    9617            5825   4366               2469
# 8  2010    9          23    9062            6220   4100               2301
# 9  2010   10          24    9638            6665   4227               2637
#
#    Abusos sexuales y otros delitos sexuales  \
# 0                                       657
# 1                                       593
# ...

# %%
df.describe ()
# Out:
#                AÑO         MES  Homicidios        Hurtos  Lesiones leves  \
# count   162.000000  162.000000  162.000000    162.000000      162.000000
# mean   2016.111111    6.388889   29.259259   8339.296296     4272.376543
# std       4.107258    3.460962   13.432858   1724.211253     1159.300255
# min    2010.000000    1.000000   10.000000   3636.000000     1965.000000
# 25%    2013.000000    3.000000   20.000000   7878.500000     3495.750000
# 50%    2016.000000    6.000000   26.000000   8861.500000     4062.500000
# 75%    2020.000000    9.000000   35.000000   9517.750000     4959.250000
# max    2023.000000   12.000000   73.000000  10738.000000     7101.000000
#
#              Robos  Robo de vehículo   \
# count   162.000000         162.000000
# mean   4986.506173        2357.271605
# std     994.751751         379.892597
# min    2842.000000        1264.000000
# 25%    4232.250000        2157.250000
# 50%    4924.000000        2446.500000
# ...

# %%
print(df.isnull(). sum())
# Out:
# AÑO                                         0
# MES                                         0
# Homicidios                                  0
# Hurtos                                      0
# Lesiones leves                              0
# Robos                                       0
# Robo de vehículo                            0
# Abusos sexuales y otros delitos sexuales    0
# Violencia intrafamiliar a adulto mayor      0
# Violencia intrafamiliar a hombre            0
# Violencia intrafamiliar a mujer             0
# Violencia intrafamiliar a niño              0
# dtype: int64

# %%
mpl.style.use ("bmh")
sns.set_theme(style="whitegrid")
colors = sns.color_palette("husl", 8)

# %%
fig, ax = plt.subplots ()
ax.plot ([1,2],[3,4])

# %%
fig, ax = plt.subplots ()
ax.plot ([1,2],[3,4])
ax.set_ylim ([2,4])
ax.set_xlim ([1,3])
ax.set_ylabel ("Y")
ax.set_xlabel ("X")
ax.set_title ("gráfico de prueba")
# Out:
# Text(0.5, 1.0, 'gráfico de prueba')

# %%
fig, ax= plt.subplots ()
ax.bar ([1,2,3],[3,2,1])
plt.show()

# %%
fig, ax =plt.subplots ()
ax.pie ([5,4,3,2,1])
plt.show()

# %%
df_delitos= pd.read_excel ("estadisticas.delitos.xlsx")
plt.plot (df_delitos.Homicidios)
plt.show()

# %%
df_delitos= pd.read_excel ("estadisticas.delitos.xlsx")
fig, ax =plt.subplots()
ax.bar (df_delitos.MES,df_delitos.Homicidios)
plt.show ()
